# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

# %%
# Task 1 - Prompt
prompt_template = ChatPromptTemplate.from_messages([
    ('system', "You are a serious assistant."),
    ('human', "{input}")
])

# %%
#Task 2 - Parser

str_parser = StrOutputParser()

# %%
#Task 3 - Custom Runnable
from langchain_core.runnables import RunnableLambda

def dictionary_maker(text : str) -> dict:
    return {"text": text}

dictionary_maker_runnable = RunnableLambda(dictionary_maker)

# %%
#Task 5 
prompt_post = ChatPromptTemplate.from_messages(
    messages = [
      ('system', "You are a social media post generator."),
      ('human', "Generate a social media post for linkedin about : {text}.")
])

# %%
chain = prompt_template | llm | str_parser | dictionary_maker_runnable | prompt_post | llm | str_parser

chain.invoke("What are AI agents")
# Out:
# 'Here\'s a LinkedIn post about AI Agents, designed to be informative and engaging for a professional audience:\n\n---\n\n**Subject: Unpacking the Operational Heart of AI: Understanding AI Agents**\n\nBeyond the buzzwords, let\'s talk about the operational heart of Artificial Intelligence: **AI Agents**. These aren\'t just theoretical concepts; they are the autonomous entities that bring AI intelligence into tangible action across countless applications.\n\nAt their core, AI agents are systems designed to perceive their environment, make decisions, and act upon that environment to achieve specific goals. Think of them as the "doers" of the AI world.\n\nHere\'s a quick breakdown of what makes them tick:\n\n1.  **Environment:** The world they operate in – from a factory floor to a digital database.\n2.  **Sensors:** Their "eyes and ears" – cameras, microphones, APIs, data feeds, user input.\n3.  **Effectors:** Their "hands and voice" – robotic arms, software commands, screen displays, sending emails, updating databases.\n4.  **Agent Function (The Brain):** The internal logic that maps what they perceive to what they should do.\n\nIt\'s a continuous **Perception-Action Cycle**:\n👁️ **Perceive:** Gather information from the environment.\n🧠 **Reason:** Process information, make decisions based on goals and logic.\n⚙️ **Act:** Execute chosen actions through effectors.\n🔄 **Repeat:** Continuously adapt to the new state of the environment.\n\n**Why are AI Agents so powerful?**\n*   **Autonomy:** They operate without constant human intervention.\n*   **Proactiveness:** They initiate actions to achieve goals.\n*   **Reactivity:** They respond to environmental changes in real-time.\n*   **Goal-Oriented:** Everything they do is aimed at specific objectives.\n*   **Adaptability (for advanced agents):** Many learn and improve over time!\n\n**Examples are everywhere:**\n*   Your robotic vacuum cleaner mapping your home.\n*   Self-driving cars navigating complex roads.\n*   Chatbots and virtual assistants like Siri or Alexa.\n*   Recommendation systems suggesting your next show or product.\n*   Automated trading bots executing market orders.\n\nAI agents are the fundamental building blocks that enable everything from simple automation to complex decision-making systems, driving efficiency and innovation across every industry.\n\nWhat\'s an AI agent you interact with daily without even realizing it? Share your thoughts below!\n\n#AI #AIAgents #ArtificialIntelligence #Automation #TechInnovation #FutureOfAI #DigitalTransformation #MachineLearning #Robotics'
